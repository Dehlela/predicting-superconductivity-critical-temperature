# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
orgdata = pd.read_csv('org_data.csv')

# %%
reducedData = pd.read_csv('Reduced_Features.csv')

# %%
reducedData.describe()
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# count        21263.000000      21263.000000          21263.000000
# mean             4.115224         87.557631             72.988310
# std              1.439295         29.676497             33.490406
# min              1.000000          6.941000              6.423452
# 25%              3.000000         72.458076             52.143839
# 50%              4.000000         84.922750             60.696571
# 75%              5.000000        100.404410             86.103540
# max              9.000000        208.980400            208.980400
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# count       21263.000000           21263.000000         21263.000000
# mean           71.290627              58.539916             1.165608
# std            31.030272              36.651067             0.364930
# min             5.320573               1.960849             0.000000
# ...

# %% [raw]
# reducedData.info()

# %%
reducedData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21263 entries, 0 to 21262
# Data columns (total 52 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   number_of_elements               21263 non-null  int64
#  1   mean_atomic_mass                 21263 non-null  float64
#  2   wtd_mean_atomic_mass             21263 non-null  float64
#  3   gmean_atomic_mass                21263 non-null  float64
#  4   wtd_gmean_atomic_mass            21263 non-null  float64
#  5   entropy_atomic_mass              21263 non-null  float64
#  6   wtd_entropy_atomic_mass          21263 non-null  float64
#  7   range_atomic_mass                21263 non-null  float64
#  8   wtd_range_atomic_mass            21263 non-null  float64
#  9   std_atomic_mass                  21263 non-null  float64
#  10  wtd_std_atomic_mass              21263 non-null  float64
# ...

# %%
reducedData.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10A868C8>,
# ...
#       dtype=object)

# %%
# %matplotlib inline
reducedData.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x109A48F8>,
# ...
#       dtype=object)

# %%
reducedData.hist(bins=50, figsize=(50, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x15032100>,
# ...
#       dtype=object)

# %%
reducedData.hist(bins=50, figsize=(50, 50))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x18ABA100>,
# ...
#       dtype=object)

# %%
reducedData.hist(bins=150, figsize=(20, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1DEC07D8>,
# ...
#       dtype=object)

# %%
mainTrainData = pd.read_csv(r'Splitting\train_set.csv')

# %%
shuffled_indices = np.random.permutation(len(mainTrainData))
partition = len(mainTrainData)/10
print(len(mainTrainData),partition)
# Out:
# 17011 1701.1

# %%
for i in range(1,17012):
    if(len(mainTrainData)%i == 0):
        print(i)
# Out:
# 1
# 17011

# %%
shuffled_indices = np.random.permutation(len(mainTrainData))
partition = int(len(mainTrainData)/10)
print(len(mainTrainData),partition)
# Out:
# 17011 1701

# %%
data_indices = {}
partitioned_data = {}
counter=0
limit = len(mainTrainData)-partition-1
for i in range(0,limit,partition):
    data_indices[counter] = shuffled_indices[i:i+partition]
    partitioned_data[counter] = mainTrainData.iloc[data_indices[counter]]
    counter = counter + 1
    
data_indices[counter] = shuffled_indices[limit:]
partitioned_data[counter] = mainTrainData.iloc[data_indices[counter]]

# %%
data=pd.DataFrame()

# %%
for i in range(0,10,3):
    print(i)
# Out:
# 0
# 3
# 6
# 9

# %%
indices = range(0,10)
print(indices)
# Out:
# range(0, 10)

# %%
print(indices[0:5])
# Out:
# range(0, 5)

# %%
indices = np.random()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-2566f275ad15> in <module>
# ----> 1 indices = np.random()
#
# TypeError: 'module' object is not callable

# %%
print(type(shuffled_indices))
# Out:
# <class 'numpy.ndarray'>

# %%
mainTrainData.iloc[0,2,3]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-53-04acb461ed96> in <module>
# ----> 1 mainTrainData.iloc[0,2,3]
#
# c:\users\dehlela\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# c:\users\dehlela\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2064     def _getitem_tuple(self, tup: Tuple):
#    2065
# -> 2066         self._has_valid_tuple(tup)
#    2067         try:
#    2068             return self._getitem_lowerdim(tup)
#
# ...
